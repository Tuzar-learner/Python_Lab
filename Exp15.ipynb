# %%
import matplotlib.pyplot as plt
def f(x):
    return pow(x,4) + 5
x = [1,2,3,4,5,6]
res = []
for i in x:
    y = f(i)
    res.append(y)
plt.plot(res)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid()
